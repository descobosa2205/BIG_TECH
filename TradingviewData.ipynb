# %%
from TradingviewData import TradingViewData,Interval

request = TradingViewData()

# %%
request.search('METAL','MCX')
# Out:
# ERROR:TradingviewData.main:Expecting value: line 1 column 1 (char 0)
# []

# %%
avax_data = request.get_hist(symbol='AVAXUSD',exchange='Binance',interval=Interval.daily,n_bars=1461)

avax_data
# Out:
#                               symbol       open       high        low  \
# datetime
# 2022-01-23 01:00:00  Binance:AVAXUSD  59.853796  66.889643  59.038229
# 2022-01-24 01:00:00  Binance:AVAXUSD  64.852785  64.854387  55.236679
# 2022-01-25 01:00:00  Binance:AVAXUSD  62.978926  70.658855  61.710777
# 2022-01-26 01:00:00  Binance:AVAXUSD  68.057846  73.243396  64.502906
# 2022-01-27 01:00:00  Binance:AVAXUSD  65.879000  67.951789  61.139137
# ...                              ...        ...        ...        ...
# 2026-01-18 01:00:00  Binance:AVAXUSD  13.756693  13.816375  12.944312
# 2026-01-19 01:00:00  Binance:AVAXUSD  12.934844  12.934844  12.107551
# 2026-01-20 01:00:00  Binance:AVAXUSD  12.729060  12.750175  11.987247
# 2026-01-21 01:00:00  Binance:AVAXUSD  12.070179  12.718044  11.879563
# 2026-01-22 01:00:00  Binance:AVAXUSD  12.420160  12.614316  12.040973
#
#                          close     volume
# datetime
# 2022-01-23 01:00:00  64.878152  268105.18
# 2022-01-24 01:00:00  63.088485  224702.52
# 2022-01-25 01:00:00  68.027966  206129.22
# 2022-01-26 01:00:00  65.886976  250217.52
# 2022-01-27 01:00:00  64.792479  144499.26
# ...                        ...        ...
# 2026-01-18 01:00:00  12.980054   77268.91
# 2026-01-19 01:00:00  12.718677  164370.02
# 2026-01-20 01:00:00  12.085603   93001.36
# 2026-01-21 01:00:00  12.408907  108129.93
# 2026-01-22 01:00:00  12.147093   49550.39
#
# [1461 rows x 6 columns]

# %%
avax_data["close"].isna().count() # No hay ningún dato faltante
# Out:
# np.int64(1461)

# %%
avax_data["close"].min(), avax_data["close"].max()
# Out:
# (np.float64(8.779517), np.float64(98.0305709))

# %%
avax_data.to_csv("avax_data.csv")

# %%
avax_data.close.plot(figsize=(15,10),use_index=False)
# Out:
# <Axes: >
